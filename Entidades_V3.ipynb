# %%
import numpy as np
import pandas as pd
import spacy
from spacy.tokens import Doc, Span

archivo = pd.read_excel("listado de especificaciones para proyecto.xlsx", sheet_name= "Especificaciones sin código ine")
medicamentos = archivo
medicamentos.head(3)
# Out:
#   Responsable  Renglón  Cód-INE            NOMBRE
# 0        dANY        1  475-016  Sevoflurano 100%  \
# 1        dANY        2  476-028   Isoflurano 100%
# 2        dANY        3  477-016   Desflurano 100%
#
#                          CARACTERÍSTICAS SOLICITADAS Presentación
# 0  100%. Solución para inhalación. Frasco 250 ml....       Frasco  \
# 1  100%. Solución para inhalación. Frasco 100-250...       Frasco
# 2  100%. Solución para inhalación. Frasco 240 ml....       Frasco
#
#   CANTIDAD ESTIMADA 24 MESES MSPAS VIA DE ADMINISTRACIÓN UNIDAD DE MEDIDA
# 0                            13400           INHALATORIA           Unidad  \
# 1                           700000           INHALATORIA        Mililitro
# 2                             1100           INHALATORIA           Unidad
#
#    RENGLÓN  AREA  CORRELATIVO                                 RUBRO
# 0      266     4           41  ANESTESICOS GENERALES Y/O INDUCTORES  \
# 1      266     4           81  ANESTESICOS GENERALES Y/O INDUCTORES
# 2      266     4          221  ANESTESICOS GENERALES Y/O INDUCTORES
#
#   REQUIERE REGISTRA SANITARIO Observaciones
# 0                          SI           NaN
# 1                          SI           NaN
# 2                          SI           NaN

# %%
nombre_medicamentos = medicamentos["NOMBRE"].tolist()

# %%
import unicodedata
import re
regex = r'^([A-Za-zÀ-ÿ\s]+)(?:\s+[A-Za-zÀ-ÿ\s]+)*\s*'

def limpiar_texto(texto):
    texto = unicodedata.normalize('NFD', texto)  # Elimina tildes
    texto = texto.lower()  # Convierte a minúsculas
    return texto.strip() 

# Aplicar la expresión regular y limpiar el texto a cada elemento de la lista
nombres_medicamentos_reg = [limpiar_texto(re.match(regex, medicamento).group(1)) for medicamento in nombre_medicamentos]

# Imprimir los nombres de los medicamentos
for nombre in nombres_medicamentos_reg:
    print(nombre)
# Out:
# sevoflurano
# isoflurano
# desflurano
# ketamina
# propofol
# propofol
# bupivacaina clorhidrato sin epinefrina sin preservantes
# bupivacaina pesada
# lidocaina clorhidrato con epinefrina sin preservante
# lidocaina clorhidrato sin epinefrina con preservante
# lidocaina dental sin epinefrina
# lidocaina dental con epinefrina
# lidocaina clorhidrato sin epinefrina
# carbamazepina
# carbamazepina
# fenitoina sódica
# fenitoina sódica
# ácido valproico
# ácido valproico
# ácido valproico
# fenobarbital
# fenobarbital
# gabapentina
# lamotrigina
# carbonato de litio
# sertralina hidrocloruro
# naloxona
# flumazenil
# deferasirox
# biperideno clorhidrato
# agua estéril para inyección
# agua estéril para inyección
# cloruro de sodio
# cloruro de sodio
# cloruro de sodio
# aminoácidos sin electrolitos pediátricos
# aminoácidos para paciente hepático
# aminoácidos con electrolitos
# aminoácidos sin electrolitos
# magnesio sulfato
# calcio gluconato
# dextrosa
# dextrosa
# dextrosa
# dextrosa
# dextrosa
# dextrosa
# dextrosa
# dextrosa
# lípidos
# lipidos mct
# oligoelementos
# cloruro de potasio
# bicarbonato de sodio
# cloruro de sodio
# cloruro de sodio
# cloruro de sodio
# solución no
# solución no
# solución no
# solución no
# poligelina con electrolitos
# emulsión inyectable
# emulsión inyectable
# cloruro de sodio
# cloruro de sodio
# cloruro de sodio
# gelatina succinilada
# hidroxietil almidón
# magnesio sulfato
# sales de rehidratación oral
# eritropoyetina humana recombinante
# eritropoyetina humana recombinante
# bromhexina
# carboximetilcisteina
# guayacolato de glicerilo
# ambroxol
# ergonovina maleato
# oxitocina sintética
# carbetocina
# clorpromazina
# haloperidol
# haloperidol
# clozapina
# risperidona
# olanzapina
# quetiapina
# alprazolam
# clonazepam
# diazepam
# lorazepam
# surfactante pulmonar
# surfactante pulmonar
# ritodrina

# %%
nombres_medicamentos_reg
# Out:
# ['sevoflurano',
#  'isoflurano',
#  'desflurano',
#  'ketamina',
#  'propofol',
#  'propofol',
#  'bupivacaina clorhidrato sin epinefrina sin preservantes',
#  'bupivacaina pesada',
#  'lidocaina clorhidrato con epinefrina sin preservante',
#  'lidocaina clorhidrato sin epinefrina con preservante',
#  'lidocaina dental sin epinefrina',
#  'lidocaina dental con epinefrina',
#  'lidocaina clorhidrato sin epinefrina',
#  'carbamazepina',
#  'carbamazepina',
#  'fenitoina sódica',
#  'fenitoina sódica',
#  'ácido valproico',
#  'ácido valproico',
#  'ácido valproico',
#  'fenobarbital',
#  'fenobarbital',
#  'gabapentina',
#  'lamotrigina',
#  'carbonato de litio',
#  'sertralina hidrocloruro',
#  'naloxona',
#  'flumazenil',
#  'deferasirox',
#  'biperideno clorhidrato',
#  'agua estéril para inyección',
#  'agua estéril para inyección',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'aminoácidos sin electrolitos pediátricos',
#  'aminoácidos para paciente hepático',
#  'aminoácidos con electrolitos',
#  'aminoácidos sin electrolitos',
#  'magnesio sulfato',
#  'calcio gluconato',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'lípidos',
#  'lipidos mct',
#  'oligoelementos',
#  'cloruro de potasio',
#  'bicarbonato de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'solución no',
#  'solución no',
#  'solución no',
#  'solución no',
#  'poligelina con electrolitos',
#  'emulsión inyectable',
#  'emulsión inyectable',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'gelatina succinilada',
#  'hidroxietil almidón',
#  'magnesio sulfato',
#  'sales de rehidratación oral',
#  'eritropoyetina humana recombinante',
#  'eritropoyetina humana recombinante',
#  'bromhexina',
#  'carboximetilcisteina',
#  'guayacolato de glicerilo',
#  'ambroxol',
#  'ergonovina maleato',
#  'oxitocina sintética',
#  'carbetocina',
#  'clorpromazina',
#  'haloperidol',
#  'haloperidol',
#  'clozapina',
#  'risperidona',
#  'olanzapina',
#  'quetiapina',
#  'alprazolam',
#  'clonazepam',
#  'diazepam',
#  'lorazepam',
#  'surfactante pulmonar',
#  'surfactante pulmonar',
#  'ritodrina']

# %%
"""medicamento_patterns = {}

for medicamento in nombres_medicamentos_reg:
    # Dividir el nombre del medicamento en palabras separadas
    palabras = medicamento.split()
    
    # Crear un patrón para el medicamento como una lista de palabras
    patron = [{"lower": palabra} for palabra in palabras]
    
    # Agregar el patrón al diccionario, utilizando el nombre del medicamento como clave
    medicamento_patterns[medicamento] = patron"""
# Out:
# 'medicamento_patterns = {}\n\nfor medicamento in nombres_medicamentos_reg:\n    # Dividir el nombre del medicamento en palabras separadas\n    palabras = medicamento.split()\n    \n    # Crear un patrón para el medicamento como una lista de palabras\n    patron = [{"lower": palabra} for palabra in palabras]\n    \n    # Agregar el patrón al diccionario, utilizando el nombre del medicamento como clave\n    medicamento_patterns[medicamento] = patron'

# %%
#pip install --upgrade spacy

# %%
nlp = spacy.load("es_core_news_lg")

# Obtener el componente ner del pipeline
ner = nlp.get_pipe("ner")

# Crear un diccionario de patrones de medicamentos
medicamento_patterns = {}

for medicamento in nombres_medicamentos_reg:
    # Dividir el nombre del medicamento en palabras separadas
    palabras = medicamento.split()
    
    # Crear un patrón para el medicamento como una lista de palabras
    patron = [{"lower": palabra} for palabra in palabras]
    
    # Agregar el patrón al diccionario, utilizando el nombre del medicamento como clave
    medicamento_patterns[medicamento] = patron

# Crear etiquetas de entidad personalizadas para cada medicamento y agregarlas al componente ner
for medicamento, patron in medicamento_patterns.items():
    ner.add_label(medicamento)

# %%
medicamento_patterns
# Out:
# {'sevoflurano': [{'lower': 'sevoflurano'}],
#  'isoflurano': [{'lower': 'isoflurano'}],
#  'desflurano': [{'lower': 'desflurano'}],
#  'ketamina': [{'lower': 'ketamina'}],
#  'propofol': [{'lower': 'propofol'}],
#  'bupivacaina clorhidrato sin epinefrina sin preservantes': [{'lower': 'bupivacaina'},
#   {'lower': 'clorhidrato'},
#   {'lower': 'sin'},
#   {'lower': 'epinefrina'},
#   {'lower': 'sin'},
#   {'lower': 'preservantes'}],
#  'bupivacaina pesada': [{'lower': 'bupivacaina'}, {'lower': 'pesada'}],
#  'lidocaina clorhidrato con epinefrina sin preservante': [{'lower': 'lidocaina'},
#   {'lower': 'clorhidrato'},
#   {'lower': 'con'},
#   {'lower': 'epinefrina'},
#   {'lower': 'sin'},
#   {'lower': 'preservante'}],
#  'lidocaina clorhidrato sin epinefrina con preservante': [{'lower': 'lidocaina'},
#   {'lower': 'clorhidrato'},
#   {'lower': 'sin'},
#   {'lower': 'epinefrina'},
#   {'lower': 'con'},
#   {'lower': 'preservante'}],
#  'lidocaina dental sin epinefrina': [{'lower': 'lidocaina'},
#   {'lower': 'dental'},
#   {'lower': 'sin'},
#   {'lower': 'epinefrina'}],
#  'lidocaina dental con epinefrina': [{'lower': 'lidocaina'},
#   {'lower': 'dental'},
#   {'lower': 'con'},
#   {'lower': 'epinefrina'}],
#  'lidocaina clorhidrato sin epinefrina': [{'lower': 'lidocaina'},
#   {'lower': 'clorhidrato'},
#   {'lower': 'sin'},
#   {'lower': 'epinefrina'}],
#  'carbamazepina': [{'lower': 'carbamazepina'}],
#  'fenitoina sódica': [{'lower': 'fenitoina'}, {'lower': 'sódica'}],
#  'ácido valproico': [{'lower': 'ácido'}, {'lower': 'valproico'}],
#  'fenobarbital': [{'lower': 'fenobarbital'}],
#  'gabapentina': [{'lower': 'gabapentina'}],
#  'lamotrigina': [{'lower': 'lamotrigina'}],
#  'carbonato de litio': [{'lower': 'carbonato'},
#   {'lower': 'de'},
#   {'lower': 'litio'}],
#  'sertralina hidrocloruro': [{'lower': 'sertralina'},
#   {'lower': 'hidrocloruro'}],
#  'naloxona': [{'lower': 'naloxona'}],
#  'flumazenil': [{'lower': 'flumazenil'}],
#  'deferasirox': [{'lower': 'deferasirox'}],
#  'biperideno clorhidrato': [{'lower': 'biperideno'}, {'lower': 'clorhidrato'}],
#  'agua estéril para inyección': [{'lower': 'agua'},
#   {'lower': 'estéril'},
#   {'lower': 'para'},
#   {'lower': 'inyección'}],
#  'cloruro de sodio': [{'lower': 'cloruro'},
#   {'lower': 'de'},
#   {'lower': 'sodio'}],
#  'aminoácidos sin electrolitos pediátricos': [{'lower': 'aminoácidos'},
#   {'lower': 'sin'},
#   {'lower': 'electrolitos'},
#   {'lower': 'pediátricos'}],
#  'aminoácidos para paciente hepático': [{'lower': 'aminoácidos'},
#   {'lower': 'para'},
#   {'lower': 'paciente'},
#   {'lower': 'hepático'}],
#  'aminoácidos con electrolitos': [{'lower': 'aminoácidos'},
#   {'lower': 'con'},
#   {'lower': 'electrolitos'}],
#  'aminoácidos sin electrolitos': [{'lower': 'aminoácidos'},
#   {'lower': 'sin'},
#   {'lower': 'electrolitos'}],
#  'magnesio sulfato': [{'lower': 'magnesio'}, {'lower': 'sulfato'}],
#  'calcio gluconato': [{'lower': 'calcio'}, {'lower': 'gluconato'}],
#  'dextrosa': [{'lower': 'dextrosa'}],
#  'lípidos': [{'lower': 'lípidos'}],
#  'lipidos mct': [{'lower': 'lipidos'}, {'lower': 'mct'}],
#  'oligoelementos': [{'lower': 'oligoelementos'}],
#  'cloruro de potasio': [{'lower': 'cloruro'},
#   {'lower': 'de'},
#   {'lower': 'potasio'}],
#  'bicarbonato de sodio': [{'lower': 'bicarbonato'},
#   {'lower': 'de'},
#   {'lower': 'sodio'}],
#  'solución no': [{'lower': 'solución'}, {'lower': 'no'}],
#  'poligelina con electrolitos': [{'lower': 'poligelina'},
#   {'lower': 'con'},
#   {'lower': 'electrolitos'}],
#  'emulsión inyectable': [{'lower': 'emulsión'}, {'lower': 'inyectable'}],
#  'gelatina succinilada': [{'lower': 'gelatina'}, {'lower': 'succinilada'}],
#  'hidroxietil almidón': [{'lower': 'hidroxietil'}, {'lower': 'almidón'}],
#  'sales de rehidratación oral': [{'lower': 'sales'},
#   {'lower': 'de'},
#   {'lower': 'rehidratación'},
#   {'lower': 'oral'}],
#  'eritropoyetina humana recombinante': [{'lower': 'eritropoyetina'},
#   {'lower': 'humana'},
#   {'lower': 'recombinante'}],
#  'bromhexina': [{'lower': 'bromhexina'}],
#  'carboximetilcisteina': [{'lower': 'carboximetilcisteina'}],
#  'guayacolato de glicerilo': [{'lower': 'guayacolato'},
#   {'lower': 'de'},
#   {'lower': 'glicerilo'}],
#  'ambroxol': [{'lower': 'ambroxol'}],
#  'ergonovina maleato': [{'lower': 'ergonovina'}, {'lower': 'maleato'}],
#  'oxitocina sintética': [{'lower': 'oxitocina'}, {'lower': 'sintética'}],
#  'carbetocina': [{'lower': 'carbetocina'}],
#  'clorpromazina': [{'lower': 'clorpromazina'}],
#  'haloperidol': [{'lower': 'haloperidol'}],
#  'clozapina': [{'lower': 'clozapina'}],
#  'risperidona': [{'lower': 'risperidona'}],
#  'olanzapina': [{'lower': 'olanzapina'}],
#  'quetiapina': [{'lower': 'quetiapina'}],
#  'alprazolam': [{'lower': 'alprazolam'}],
#  'clonazepam': [{'lower': 'clonazepam'}],
#  'diazepam': [{'lower': 'diazepam'}],
#  'lorazepam': [{'lower': 'lorazepam'}],
#  'surfactante pulmonar': [{'lower': 'surfactante'}, {'lower': 'pulmonar'}],
#  'ritodrina': [{'lower': 'ritodrina'}]}

# %%
indice = 1
for ent in doc.ents:
    print(f"ID: {indice} - Texto: {ent.text} ---> Etiqueta: {ent.label_}")
    indice += 1

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import Span

# Cargar un modelo de spaCy
nlp = spacy.load("es_core_news_lg")

# Obtener el componente ner del pipeline
ner = nlp.get_pipe("ner")

# Crear un diccionario de patrones de medicamentos

# Crear un Matcher
matcher = Matcher(nlp.vocab)

# Agregar los patrones de medicamentos al Matcher
for medicamento, patron in medicamento_patterns.items():
    matcher.add(medicamento, [patron])

# %%
# Definir una función para manejar las coincidencias del Matcher
def on_match_callback(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = Span(doc, start, end, label="MEDICAMENTO")
    doc.ents = [e for e in doc.ents if not (e.start < span.end and e.end > span.start)]  # Eliminar entidades superpuestas
    doc.ents = list(doc.ents) + [span]  # Agregar la nueva entidad

# Procesar un texto
text = "LIDOCAINA CLORHIDRATO CON EPINEFRINA SIN PRESERVANTE AL 2% Y 1:100,000 50ML, VIAL."
doc = nlp(text)

matches = matcher(doc)
for match_id, start, end in matches:
    on_match_callback(matcher, doc, 0, [(match_id, start, end)])
    
# Imprimir las entidades encontradas en el documento
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# LIDOCAINA CLORHIDRATO CON EPINEFRINA SIN PRESERVANTE MEDICAMENTO
# VIAL LOC

# %%
id_token = 1

# Iterar a través de los tokens en el documento
for token in doc:
    entity_info = f"{token.ent_iob_}-{token.ent_type_}" if token.ent_iob_ != 'O' else 'O'
    print(f"ID: {id_token} - Token: {token.text} - Entidad: {entity_info}")
    id_token += 1
# Out:
# ID: 1 - Token: ISOFLURANO - Entidad: B-MEDICAMENTO
# ID: 2 - Token: LÍQUIDO - Entidad: O
# ID: 3 - Token: VOLÁTIL - Entidad: B-MISC
# ID: 4 - Token: , - Entidad: O
# ID: 5 - Token: FRASCO - Entidad: B-MISC
# ID: 6 - Token: 100 - Entidad: O
# ID: 7 - Token: ML - Entidad: O

# %%
nombres_medicamentos_reg
# Out:
# ['sevoflurano',
#  'isoflurano',
#  'desflurano',
#  'ketamina',
#  'propofol',
#  'propofol',
#  'bupivacaina clorhidrato sin epinefrina sin preservantes',
#  'bupivacaina pesada',
#  'lidocaina clorhidrato con epinefrina sin preservante',
#  'lidocaina clorhidrato sin epinefrina con preservante',
#  'lidocaina dental sin epinefrina',
#  'lidocaina dental con epinefrina',
#  'lidocaina clorhidrato sin epinefrina',
#  'carbamazepina',
#  'carbamazepina',
#  'fenitoina sódica',
#  'fenitoina sódica',
#  'ácido valproico',
#  'ácido valproico',
#  'ácido valproico',
#  'fenobarbital',
#  'fenobarbital',
#  'gabapentina',
#  'lamotrigina',
#  'carbonato de litio',
#  'sertralina hidrocloruro',
#  'naloxona',
#  'flumazenil',
#  'deferasirox',
#  'biperideno clorhidrato',
#  'agua estéril para inyección',
#  'agua estéril para inyección',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'aminoácidos sin electrolitos pediátricos',
#  'aminoácidos para paciente hepático',
#  'aminoácidos con electrolitos',
#  'aminoácidos sin electrolitos',
#  'magnesio sulfato',
#  'calcio gluconato',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'dextrosa',
#  'lípidos',
#  'lipidos mct',
#  'oligoelementos',
#  'cloruro de potasio',
#  'bicarbonato de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'solución no',
#  'solución no',
#  'solución no',
#  'solución no',
#  'poligelina con electrolitos',
#  'emulsión inyectable',
#  'emulsión inyectable',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'cloruro de sodio',
#  'gelatina succinilada',
#  'hidroxietil almidón',
#  'magnesio sulfato',
#  'sales de rehidratación oral',
#  'eritropoyetina humana recombinante',
#  'eritropoyetina humana recombinante',
#  'bromhexina',
#  'carboximetilcisteina',
#  'guayacolato de glicerilo',
#  'ambroxol',
#  'ergonovina maleato',
#  'oxitocina sintética',
#  'carbetocina',
#  'clorpromazina',
#  'haloperidol',
#  'haloperidol',
#  'clozapina',
#  'risperidona',
#  'olanzapina',
#  'quetiapina',
#  'alprazolam',
#  'clonazepam',
#  'diazepam',
#  'lorazepam',
#  'surfactante pulmonar',
#  'surfactante pulmonar',
#  'ritodrina']
